# %%
# !pip install scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 7.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.7/28.7 MB 7.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 7.7 MB/s eta 0:00:00
# ...

# %%
from sklearn import tree
import pandas as pd
import matplotlib as plt
import seaborn as sns
import math
# %matplotlib inline

# %%
data = pd.DataFrame({'X_1': [1, 1, 1, 0, 0, 0, 0, 1], 'X_2': [0, 0, 0, 1, 0, 0, 0, 1], 'Y': [1, 1, 1, 1, 0, 0, 0, 0]})

# %%
data
# Out:
#    X_1  X_2  Y
# 0    1    0  1
# 1    1    0  1
# 2    1    0  1
# 3    0    1  1
# 4    0    0  0
# 5    0    0  0
# 6    0    0  0
# 7    1    1  0

# %%
clf = tree.DecisionTreeClassifier(criterion='entropy')

# %%
clf
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
X = data[['X_1', 'X_2']]

# %%
y = data.Y

# %%
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
tree.plot_tree(clf, filled=True)
# Out:
# [Text(0.5, 0.8333333333333334, 'x[0] <= 0.5\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.25, 0.5, 'x[1] <= 0.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.125, 0.16666666666666666, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.375, 0.16666666666666666, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.75, 0.5, 'x[1] <= 0.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.625, 0.16666666666666666, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.875, 0.16666666666666666, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %%
dogs = pd.read_csv("dogs.csv", index_col=0)

# %%
dogs
# Out:
#    Шерстист  Гавкает  Лазает по деревьям      Вид
# 0         1        1                   0  собачка
# 1         1        1                   0  собачка
# 2         1        1                   0  собачка
# 3         1        1                   0  собачка
# 4         1        0                   1    котик
# 5         1        0                   1    котик
# 6         1        0                   1    котик
# 7         1        0                   1    котик

# %%
X = dogs.iloc[:, 0:3]
y = dogs.iloc[:,3]

# %%
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
tree.plot_tree(clf, filled=True)
# Out:
# [Text(0.5, 0.75, 'x[1] <= 0.5\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.25, 0.25, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.75, 0.25, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]')]

# %%
E1_0 = -1 * math.log2(1)
E1_1 = -4/9 * math.log2(4/9) - 5/9 * math.log2(5/9)
E2_0 = 0 - 1 * math.log2(1)
E2_1 = -1/5 * math.log2(1/5) - 4/5 * math.log2(4/5)
E3_0 = -1 * math.log2(1)
E3_1 = -1 * math.log2(1)

# %%
print(E1_0, E1_1, E2_0, E2_1, E3_0, E3_1)
# Out:
# -0.0 0.9910760598382222 0.0 0.7219280948873623 -0.0 -0.0

# %%
EY = -4/10 * math.log2(4/10) -6/10 * math.log2(6/10)

# %%
EX1 = 1/10 * E1_0 + 9/10 * E1_1
EX2 = 1/2 * E2_0 + 1/2 * E2_1
EX3 = 4/10 * E3_0 + 6/10 * E3_1

# %%
IG1 = EY - EX1
IG2 = EY - EX2
IG3 = EY - EX3

# %%
print(round(IG1, 2), round(IG2, 2), round(IG3,2))
# Out:
# 0.08 0.61 0.97

# %%
print(round(0.053,2))
# Out:
# 0.05
